# %% [markdown]
# ---
# title: Stable diffusion using 🤗 Hugging Face - Introduction
# author: Aayush Agrawal
# date: "2022-11-02"
# categories: [Stable Diffusion]
# image: "hf_emoji.png"
# format:
#     html:
#         code-fold: false
#         number-sections: true
# ---

# %% [markdown]
# > A brief introduction to start generating images from text prompts using 🤗 [hugging face](https://huggingface.co/) - [Diffusers library](https://github.com/huggingface/diffusers).

# %% [markdown]
# This is my first post of the Stable diffusion series, which I will write on Stable diffusion and other ongoing research happening in this field. Most of my learning can be attributed to knowledge acquired while doing the [*‘From Deep learning foundations to Stable Diffusion’*](https://www.fast.ai/posts/part2-2022.html) course by [FastAI](https://www.fast.ai/posts/part2-2022.html) and supplementing this with my research. The first few lessons of the FastAI course are publicly available [here](https://www.fast.ai/posts/part2-2022-preview.html), and the rest will become available in early 2023. In this post, I want to give a brief introduction of how to use setup the 🤗 diffusion library and start generating images on your own. Next post, we will do a deep dive into mid-level components of this library.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Stable diffusion simply put is a deep learning model which can generate an image given a textual prompt.

# %% [markdown]
# <figure align = "center">
# <img src="./sd_overview.png" style="width:100%">
# <figcaption align = "center">
#         Fig. 1: Stable diffusion overview
# </figcaption>
# </figure>

# %% [markdown]
# As we can see from the image above we can pass a textual prompt like "A dog wearing a hat" and a stable diffusion model can generate an image representative of the text. Pretty amazing!

# %% [markdown]
# ## Using Hugging face Diffuser library

# %% [markdown]
# As with any python library, we need to follow certain installation steps before we can run it, here is a rundown of these steps.

# %% [markdown]
# ### Accepting the license

# %% [markdown]
# Before using the model, you need to go [here](https://huggingface.co/CompVis/stable-diffusion-v1-4) and log in using your Hugging face account and then accept the model license to download and use the weights.

# %% [markdown]
# ### Token generation

# %% [markdown]
# If this is your first time using the hugging face library this might sound like a weird step. You need to go [here](https://huggingface.co/settings/tokens) and generate a token (preferably with write access) to download the model.

# %% [markdown]
# <figure align = "center">
# <img src="./access_token.png" style="width:100%">
# <figcaption align = "center">
#         Fig. 2: Access token page
# </figcaption>
# </figure>

# %% [markdown]
# Once you have generated the token copy it. First, we will download the hugging face hub library using the following code.

# %%
#| code-fold: false
# !pip install huggingface-hub==0.10.1

# %% [markdown]
# Then use the following code, once you run it a widget will appear, paste your newly generated token and click login.

# %%
#| code-fold: false
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /home/aayush/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %% [markdown]
# ### Installing diffuser and transformer library

# %% [markdown]
# Once this process is done, install the dependencies using the following code. This will download the latest version of the [diffusers](https://github.com/huggingface/diffusers) and [transformers](https://github.com/huggingface/transformers) library.

# %%
#| code-fold: false
# !pip install -qq -U diffusers transformers

# %% [markdown]
# That's it, now we are ready to use the diffusers library.

# %% [markdown]
# ## Running Stable Diffusion

# %% [markdown]
# The first step is to import the `StableDiffusionPipeline` from the diffusers library.

# %%
#| code-fold: false
from diffusers import StableDiffusionPipeline

# %% [markdown]
# The next step is to initialize a pipeline to generate an image. The first time you run the following command, it will download the model from the hugging face model hub to your local machine. You will require a GPU machine to be able to run this code.

# %%
pipe = StableDiffusionPipeline.from_pretrained('CompVis/stable-diffusion-v1-4').to('cuda')
# Out:
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/289 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/592 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]

# %% [markdown]
# Now let's pass a textual prompt and generate an image.

# %%
#| fig-cap: Fig 3 - An example of image generated by the diffuser pipeline.

# Initialize a prompt
prompt = "a dog wearing hat"
# Pass the prompt in the pipeline
pipe(prompt).images[0]
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# For further information on the diffusion pipeline read the documentation [here](Stable diffusion pipelines).

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this post, we saw how to install diffusers library from hugging face and use the Stable diffusion model to generate images using a textual prompt. Read the [part 2 here](https://aayushmnit.com/posts/2022-11-05-StableDiffusionP2/2022-11-05-StableDiffusionP2.html).

# %% [markdown]
# I hope you enjoyed reading it, and feel free to use my code and try it out for generating your images. Also, if there is any feedback on the code or just the blog post, feel free to reach out on [LinkedIn](https://www.linkedin.com/in/aayushmnit/) or email me at aayushmnit@gmail.com.
